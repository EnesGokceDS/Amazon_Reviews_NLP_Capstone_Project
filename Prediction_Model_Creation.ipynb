# %% [markdown]
# <a href="https://colab.research.google.com/github/EnesGokceDS/Amazon_Reviews_NLP_Capstone_Project/blob/master/Prediction_Model_Creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import subprocess as sp
import sys,os,shutil,pickle,time
from os.path import join
# mount Google Drive
from os.path import expanduser
gd_path=join(expanduser("~"),'gd')
if not os.path.isdir(gd_path):
    try:
        # load Google Drive
        from google.colab import drive,files
        drive.mount('/drive')
        sp.call('ln -s /drive/My\ Drive '+gd_path, shell=True)
    except:
        print('unable to find Google Drive Folder')
os.chdir(gd_path+'/MachineLearning/NLP_capstone_data')
os.listdir('.')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /drive
# ['Reviews.csv',
#  'Amazon_logo.PNG',
#  'Amazon_reviews_processed.csv',
#  'Amazon_reviews_cleaned_finalform.csv',
#  'Amazon_reviews_after_sentiment.csv']

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Amazon_reviews_after_sentiment.csv')
df.head(5)
# Out:
#    Id   ProductId          UserId  ...  Good_reviews  polarity  subjectivity
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW  ...             1      0.42          0.40
# 1   2  B00813GRG4  A1D87F6ZCVE5NK  ...             0      0.22          0.76
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  ...             1      0.19          0.55
# 3   4  B000UA0QIQ  A395BORC6FGVXV  ...             0      0.15          0.65
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T  ...             1      0.46          0.60
#
# [5 rows x 19 columns]

# %%
df= df.drop(['UserId', 'Summary', 'Time',"ProductId"], axis=1)
df.head()
# Out:
#    Id  HelpfulnessNumerator  ...  polarity  subjectivity
# 0   1                     1  ...      0.42          0.40
# 1   2                     0  ...      0.22          0.76
# 2   3                     1  ...      0.19          0.55
# 3   4                     3  ...      0.15          0.65
# 4   5                     0  ...      0.46          0.60
#
# [5 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392718 entries, 0 to 392717
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      392718 non-null  int64
#  1   HelpfulnessNumerator    392718 non-null  int64
#  2   HelpfulnessDenominator  392718 non-null  int64
#  3   Score                   392718 non-null  int64
#  4   Text                    392717 non-null  object
#  5   stopwords               392718 non-null  int64
#  6   punctuation             392718 non-null  int64
#  7   numerics                392718 non-null  int64
#  8   upper                   392718 non-null  int64
#  9   word_count              392718 non-null  int64
#  10  char_count              392718 non-null  int64
#  11  avg_word                392718 non-null  float64
#  12  Good_reviews            392718 non-null  int64
#  13  polarity                392718 non-null  float64
#  14  subjectivity            392718 non-null  float64
# dtypes: float64(3), int64(11), object(1)
# memory usage: 44.9+ MB

# %%
df['Text']= df['Text'].astype(str)

# %% [markdown]
# ### **Create document term matrix with TF-IDF**

# %% [markdown]
# ### Split Train and Test data

# %%
from sklearn.model_selection import train_test_split

y= df.Good_reviews.values 
X= df.Text

X_train, X_test, y_train, y_test = train_test_split( 
           X, y, test_size = 0.33, random_state = 820) 


print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (263121,) (263121,)
# (129597,) (129597,)

# %% [markdown]
# ### **Scale the data with Standard Scaler**

# %%
# Feature Scaling
#from sklearn.preprocessing import StandardScaler

#sc = StandardScaler()
#X_train= sc.fit_transform(X_train)
#X_test= sc.transform(X_test)

# %% [markdown]
# ### Convert reviews to a matrix of TF-IDF features

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfi = TfidfVectorizer(ngram_range=(1,3), max_features = 2000)

X_train_tfi = tfi.fit_transform(X_train).toarray() 
X_test_tfi = tfi.transform(X_test).toarray()

# %% [markdown]
# Now, the data is ready for deploying machine learning models for prediction.

# %% [markdown]
# ## **Naive Bayes with Gaussian Method**

# %% [markdown]
# Deploying Naive Bayes Models
#
# https://scikit-learn.org/stable/modules/naive_bayes.html#bernoulli-naive-bayes
# Scikit-learn page suggest to evaluate different Naive Bayes models, if time permits.
#
# In this study, I will evaluate:
#
# 1.   Gaussian Method
# 2.   Multinominal method
# 3.   Bernoulli Method

# %%
# Fitting naive bayes to the training set with Gaussian Method
from sklearn.naive_bayes import GaussianNB 
from sklearn.metrics import confusion_matrix 
  
classifier = GaussianNB(); 
classifier.fit(X_train_tfi, y_train) 
cv_gaussian= classifier.fit(X_train_tfi, y_train) 
  
# predicting test set results 
y_pred = classifier.predict(X_test_tfi) 
  
# making the confusion matrix 
cm = confusion_matrix(y_test, y_pred) 
cm
# Out:
# array([[23338,  5251],
#        [25092, 75916]])

# %% [markdown]
# ####Model performance

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

print('Accuracy score: {0:0.2f}'.format(accuracy_score(y_test, y_pred)))
print('Precision score: {0:0.2f}'.format(precision_score(y_test, y_pred)))
print('Recall score: {0:0.2f}'.format(recall_score(y_test, y_pred)))
# Out:
# Accuracy score: 0.77
# Precision score: 0.94
# Recall score: 0.75

# %% [markdown]
# ---
# ## **Multinomial Naive Bayes**

# %%
# Fitting naive bayes to the training set with Multinomial Method
from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB()
classifier.fit(X_train_tfi, y_train) 
cv_mn = classifier.fit(X_train_tfi, y_train) 
  
# predicting test set results 
y_pred = classifier.predict(X_test_tfi) 
  
# making the confusion matrix 
cm = confusion_matrix(y_test, y_pred) 
cm
# Out:
# array([[  7352,  21237],
#        [   959, 100049]])

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(cm, square=True, annot=True, cmap='RdBu', cbar=False, fmt='d', # fmt='d' is a lifesaver. It gets rid of numbers like 1.8e + 02
xticklabels=['Bad Review', 'Good Review'],
yticklabels=['Bad Review', 'Good Review'])
plt.xlabel('True label', fontsize= 15)
plt.ylabel('Predicted label',fontsize= 15)
# Out:
# Text(91.68, 0.5, 'Predicted label')

# %% [markdown]
# #####Model's performance

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred).round(2)
# Out:
# 0.83

# %%
from sklearn.metrics import average_precision_score
average_precision = average_precision_score(y_test, y_pred)

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.82

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

print('Accuracy score: {0:0.2f}'.format(accuracy_score(y_test, y_pred)))
print('Precision score: {0:0.2f}'.format(precision_score(y_test, y_pred)))
print('Recall score: {0:0.2f}'.format(recall_score(y_test, y_pred)))
# Out:
# Accuracy score: 0.83
# Precision score: 0.82
# Recall score: 0.99

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
import matplotlib.pyplot as plt

disp = plot_precision_recall_curve(classifier, X_test_tfi, y_test)
disp.ax_.set_title('2-class Precision-Recall curve: '
                   'AP={0:0.2f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, '2-class Precision-Recall curve: AP=0.82')

# %% [markdown]
# ---
#
# ## **Bernoulli Naive Bayes**

# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import confusion_matrix 
  
classifier = BernoulliNB(); 
classifier.fit(X_train_tfi, y_train) 
cv_ber= classifier.fit(X_train_tfi, y_train) 
  
# predicting test set results 
y_pred = classifier.predict(X_test_tfi) 
  
# making the confusion matrix 
cm = confusion_matrix(y_test, y_pred) 
cm
# Out:
# array([[18058, 10531],
#        [10898, 90110]])

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(cm, square=True, annot=True, cmap='RdBu', cbar=False, fmt='d', # fmt='d' is a lifesaver. It gets rid of numbers like 1.8e + 02
xticklabels=['Bad Review', 'Good Review'],
yticklabels=['Bad Review', 'Good Review'])
plt.xlabel('True label', fontsize= 15)
plt.ylabel('Predicted label',fontsize= 15)
# Out:
# Text(91.68, 0.5, 'Predicted label')

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

print('Accuracy score: {0:0.2f}'.format(accuracy_score(y_test, y_pred)))
print('Precision score: {0:0.2f}'.format(precision_score(y_test, y_pred)))
print('Recall score: {0:0.2f}'.format(recall_score(y_test, y_pred)))
# Out:
# Accuracy score: 0.83
# Precision score: 0.90
# Recall score: 0.89

# %%
sns.set(style="white", color_codes=True)


from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
import matplotlib.pyplot as plt

disp = plot_precision_recall_curve(classifier, X_test_tfi, y_test)
disp.ax_.set_title('2-class Precision-Recall curve: '
                   'AP={0:0.2f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, '2-class Precision-Recall curve: AP=0.82')

# %% [markdown]
# ---
#
# # **Logistic Regression Model Fitting**

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter=1000)
logreg.fit(X_train_tfi, y_train)
cv_logreg= logreg.fit(X_train_tfi, y_train)

# predicting test set results 
y_pred = logreg.predict(X_test_tfi)

# %%
# making the confusion matrix 
cm = confusion_matrix(y_test, y_pred) 

sns.heatmap(cm, square=True, annot=True, cmap='RdBu', cbar=False, fmt='d',
xticklabels=['Bad Review', 'Good Review'],
yticklabels=['Bad Review', 'Good Review'])
plt.xlabel('True label', fontsize= 15)
plt.ylabel('Predicted label',fontsize= 15)
# Out:
# Text(89.18, 0.5, 'Predicted label')

# %% [markdown]
# #####Model performance evaluation

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

print('Accuracy score: {0:0.2f}'.format(accuracy_score(y_test, y_pred)))
print('Precision score: {0:0.2f}'.format(precision_score(y_test, y_pred)))
print('Recall score: {0:0.2f}'.format(recall_score(y_test, y_pred)))
# Out:
# Accuracy score: 0.88
# Precision score: 0.90
# Recall score: 0.95

# %% [markdown]
# Receiver Operating Characteristic (ROC)

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.metrics import roc_auc_score

# %%
# Get predicted probabilities for each classifiers from fitted classifiers
y_score1 = cv_gaussian.predict_proba(X_test_tfi)[:,1]
y_score2 = cv_mn.predict_proba(X_test_tfi)[:,1]
y_score3 = cv_ber.predict_proba(X_test_tfi)[:,1]
y_score4 = cv_logreg.predict_proba(X_test_tfi)[:,1]

# Plot Receiving Operating Characteristic Curve
  # Create true and false positive rates
false_positive_rate1, true_positive_rate1, threshold1 = roc_curve(y_test, y_score1)
false_positive_rate2, true_positive_rate2, threshold2 = roc_curve(y_test, y_score2)
false_positive_rate3, true_positive_rate3, threshold3 = roc_curve(y_test, y_score3)
false_positive_rate4, true_positive_rate4, threshold3 = roc_curve(y_test, y_score4)

print('roc_auc_score for Gaussian: {0:0.2f}'.format (roc_auc_score(y_test, y_score1)))
print('roc_auc_score for Multinominal: {0:0.2f}'.format (roc_auc_score(y_test, y_score2)))
print('roc_auc_score for Bernoulli: {0:0.2f}'.format (roc_auc_score(y_test, y_score3)))
print('roc_auc_score for Logistic Regression: {0:0.2f}'.format (roc_auc_score(y_test, y_score4)))
# Out:
# roc_auc_score for Gaussian: 0.84
# roc_auc_score for Multinominal: 0.90
# roc_auc_score for Bernoulli: 0.88
# roc_auc_score for Logistic Regression: 0.92

# %%
#sns.set(style="darkgrid", color_codes=True)
plt.figure(figsize= (8,8))
plt.plot(false_positive_rate1, true_positive_rate1, label="Gaussion Method NB")
plt.plot(false_positive_rate2, true_positive_rate2, label="Multinominal NB")
plt.plot(false_positive_rate3, true_positive_rate3, label="Bernoulli NB")
plt.plot(false_positive_rate4, true_positive_rate4, label="Logistic Regression")
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate', fontsize= 13)
plt.xlabel('False Positive Rate', fontsize= 13)
plt.title('Receiving Operating Characteristic (ROC) Curve ', fontsize= 14)
plt.legend()
plt.show()

# %%
#Same plot with different background color and context parameter
sns.set(style="white", color_codes=True)
sns.set_context("talk")
plt.figure(figsize= (8,8))
plt.plot(false_positive_rate1, true_positive_rate1, label="Gaussion Method NB")
plt.plot(false_positive_rate2, true_positive_rate2, label="Multinominal NB")
plt.plot(false_positive_rate3, true_positive_rate3, label="Bernoulli NB")
plt.plot(false_positive_rate4, true_positive_rate4, label="Logistic Regression")
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate', fontsize= 13)
plt.xlabel('False Positive Rate', fontsize= 13)
plt.title('Receiving Operating Characteristic(ROC) Curve for Different Models', fontsize= 14)
plt.legend()
plt.show()

# %%
# Plot ROC curves
plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic - Gaussian')
plt.plot(false_positive_rate1, true_positive_rate1)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic - Multinominal')
plt.plot(false_positive_rate2, true_positive_rate2)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic - Bernoulli')
plt.plot(false_positive_rate3, true_positive_rate3)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic - Logistic Regression')
plt.plot(false_positive_rate4, true_positive_rate4)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ## Check the results - Sanity Check

# %%
testing_predictions = []
for i in range(len(X_test)):
       if predictions[i] == 1:
        testing_predictions.append(1)
       else:
        testing_predictions.append(0)

check_df = pd.DataFrame({'actual_label': list(y_test), 'prediction': testing_predictions, 'review':list(X_test)})
check_df.head()
#Keep in mind that y_test is now defined for Logisctic Regression which is the best model for now
# Out:
#    actual_label  prediction                                             review
# 0             0           1  review generalization hoof treats indication p...
# 1             1           1  filling tasty easy use buttercream dam sed was...
# 2             1           1  tried first time last night excellent added br...
# 3             0           1  isnt whole lot special stride gum kind got ann...
# 4             1           1  regularly make flax muffins mix ground flaxmea...

# %%
check_df.sample(10)
# Out:
#         actual_label  ...                                             review
# 15814              1  ...  tried enjoy life mambo flavor chocolate chips ...
# 123871             1  ...  fan milky sugary chai tea get coffee houses li...
# 111294             1  ...  moving cross country realize favorite foods ne...
# 15484              1  ...  review according husband cuz theres way would ...
# 127245             1  ...  love cinnamon strips flavor like flavors taste...
# 34495              1  ...  unable get right cadbury american version deli...
# 61253              1  ...  mix makes excellent gluten free pizza dough tr...
# 51943              0  ...  used love milk change tune watery product sri ...
# 120299             1  ...  yum first experience larabar really liked love...
# 100270             1  ...  remember childhood days believe aint young can...
#
# [10 rows x 3 columns]

# %%
check_df.loc[(check_df.actual_label ==1) & (check_df.prediction==0)].review.sample(50).to_list()
# Out:
# ['celsius green tea raspberry acai vitamin enriched beverage contains good stuff none bad stuff sugar aspartame preservatives high fructose corn syrup artificial colors flavors however tradeoff simple flavor drink weak tasting tart aftertaste doesnt taste bad doesnt taste good either drink claim burn calories per give energy think primarily vitamins cant confirm actually burns calories however say drinking product several daysi drank one morningi lose couple pounds bad effects like get energy drinks',
#  'received three english breakfast teas instead assortment ordered great tea wrong description kept normally one return things',
#  'read reviews bought tasted sample variety pack good taste youre reading youre interested prob taste buy',
#  'pros excellent instant coffee better lot brewed coffee elsewherebr cons description order said pack ordered got packs disappointing really upsetting dont plan return since end cost fix one way coffee price paid still pay locally ordered online cant find locally misrepresentation left little bitter ironic since coffee smooth',
#  'checking product wondered expiration date end figured spice even close expiration date would matter anyway ordered midapril expiration july worries year nowbr boxes look like store much much cheaper would spend buying box time locally',
#  'id like give stars arent quite star rating slightly better taste good sickeningly sweet right size theyre really rough tongue first one two ate noticed tongue felt numb wondered caused realized roughness sucked try remember let less melt quite honestly takes little enjoyment suckers someone else called grittiness sure causes',
#  'product nice flavor however somewhat granular regular splenda dont think would baking purposesbr overallnot bad though',
#  'taste good enough caffeine per taurine per provide good long lasting pickup trace vitamins added although nice still dont make healthy beverage means would nice amazon product page listed full ingredients product things stand past week short sentence serve product description lists sugar free make sugar free version product looks like simply used product page chuckle bit right sugar free description large legal disclaimer saying actual ingredients listed may different listed websitebr contain large amount sugar ok technically high fructose corn syrup sugar keep buying paticular version future issues bombing body much caffeine taurine b vitamins draw line somewhere issue sugar content good choice taste good effective hopeful someone take time correct sugar free error expand product description main pagebr servings calories per serving per canbr sugar grams per serving canbr caffeine per serving drink canbr taurine servingbr inositol mg servingbr ginseng mgbr guarana mgbr grape seed extract lcarnatine larginine mgbr vitamins c folic acid selenium zinc ranging rda per serving',
#  'got intrigued idea snapped pea crisps much better expected found eat whole bag although oneserving supposed oz good way close bag opening unless put large zipper food storage bag like eating might get much eat everyday crispy upon opening looked like could easily go stale left open long dh thought tasted like french fries thought definitely green type taste although wasnt overpowering buy againbut since plan pace rather get tired corn oil salt added well preservatives kindbr type crunch baked cheetos arent really greasy powder residue left fingers',
#  'let preface review fact awaken isnt like energy drinks tried first isnt sweet guess sugar added description felt didnt get jolt energy gentle effect kind kept going didnt crash backside overall think great drink would use workouts need pickmeup big meeting give thumbs',
#  'first id like say ateco americolor wanted buy americolor thought purchased wrong ones theyre markers say americolor though package says ateco using markers write candy coating initially upset markers took candy coatings cold started write ink beaded didnt stay could easily wipe away paper towel realized later may condensation cold tried work easily though work writing coating comes marker paper towel near wipe marker tip post later snowman brownie pops',
# *   'product joint rescue enjoyed beloved pekinese however expiration date soon disappointing' # Forgiving customers may give high rating, bad review
# *    'received three english breakfast teas instead assortment ordered great tea wrong description kept normally one return things', # Forgiving customer

# %%
check_df.loc[(check_df.actual_label ==0) & (check_df.prediction==1)].review.sample(50).to_list()
# Out:
# ['lavazza coffee crema e gusto goodbut expires monthbr bought four knowing thisyou post expiration dates foodnow three blocks expired coffee great folks',
#  'based reiviews purchased creamer loved idea refridgeration tastes great exactly like refrigerated liquid version untill use purchase againi picky morning coffee',
#  'live middle nowhere want try new food products read often come amazoncom find products arrive felt duds recently read raving review hungry girl product decided give shot wow good may made corn tasted like rice cake good one plus cracker wrinkly brain appearanceits kind creepy wanting judge gave husband try loves snack foods eat anything tasted couple said dont need bother threw rest box away arent worth calories',
#  'anniversary blend coffee starbucks loved itbought kcups regular coffee sorry say good brewed coffee starbucks maybe brewing process enchances flavor',
#  'granola okay great awfulbr texture nicebr bit sweet taste almost sickeningly sobr paper thin almond slivers used quite sparinglybr prevalent taste coconutbr gets rather boring since enough variance ingredients make bite bit different fruit nut granola example bite may different type fruit andor nut give variety every bite exactly like previous onebr mixed bear naked fn improved',
#  'whatever dont order candy warehouse lots places get take advantage ones treat better customer service',
#  'made pancakes biscuits mix found mediocre best really tried like product taste far wanted break making things scratch worth',
#  'love coffee like oneit strong bought big box normally drink coffee creambut shouldnt bought big sizenow stuck kcupsthat dont want',
#  'item would ok wasnt delivered days till expired got people work give daybr choice expired days oh say got friday night dont go back work till monday days',
#  'never heard celsius brand canned iced tea got case review trying along coworkers shared case weve pretty much come similar conclusionsbr pros taste ok similar cannedbottled ice teas like lipton snapple tea seems almost kind energy drink without explicitly saying energy drink warning high caffeine sensitivitycontent hand contain much caffeine like red bull heart race everyone tried said felt alert without jitteryedgy feeling socalled energy drinks without crash couple hours later calories ingredients seem relatively innocuousnot lot chemicals price per works similar energytype drinks though way soda noncarbonatedbr consif dont like acai berries taste probably like tea acai somewhat tart aftertaste tea terribly remarkable compared brands like snapple arizona calorie burning claims pretty hard verify maybe drink intended boost energy workout work effectively cans didnt seem sturdy one got punctured transit several got dented probably issue shipped sure available storesbr overall ok product youll weigh pros cons mentioned like acai taste might enjoy',
#  'span classtiny length minsbr spanwe lot fun opening package discovered panels broken heres jada somewhat drafty well drafty start gingerbread house',
#  'good potato chip salt cooked olive oil sea salt good change usual crispy seem little bit thicker potato chips update personal use way much salt sorry cant handle salt least tried',
#  'come packages folded sealed shut quality uneven perhaps pears truly soft moist rest varying shades dried buying againbr received dried pears present years ago pears uniformly big moist juicy wish remembered brand cause good dried pears wonderful',
#  'calorie packs ritz snack mix boxes pack ate one pack decided watching calories mean eat food dont like taste item unpleasant want something good try ritz calorie salty sweet snack kettle mix absolutely delicious items look similar comes taste extreme opposites one awful delicious',
#  'anxious try flavors keurig coffee maker want find something like cappucino bought cafe mocha cafe escapes tastes like hot chocolate shipping almost disappointed',
#  'disclaimer may add going lot negative comments however people helped worth person right mind would avoid products causes cancer excuse everything causes cancer cop creator want mankind suffer man made calamitiesbr gum phenylalanine causes cancer goggled causes phenylalanine causes brain damage',
#  'nice traveling peanut allergic child love sunbutter packets got expire months whereas sunbutter got amazon dont expire year little disappointed probably cant finish time',
#  'good product exactly thought would little grainy satisfying might hope like recipes especially expect useful recipes product developed straight doesnt really lot flavor punch hard explain really decent product doesnt satiation real peanut butter light kind lacking flavor would probably buy often stated good recipes made pudding actually turned pretty good recipe called cocoa substituted powder tasty good straight dont expect healthier substitute pbj sandwich',
#  'come conclusion big fan things ill definitely say mango peach mio better flavors tried though tasted like glass juice flavor wasnt half bad dont understand recommend drops though one takes amount actually get flavor drink another one biggest issues mio things cant get drop squeeze shoots jet havent managed get drop peach flavor bit strong comparison mango definitely artificial candytype peach real peach flavor found flavor drinkable although still wasnt good buying juice still drinkable sweet tea flavor absolutely disgusting',
#  'kids like contain artificial ingredients cost less natural chewy bars per box store',
#  'used get years back amazing bought times taste different like theyre skimping something taste really dry kinda plain feeling recipe change something fact flavor blasted ones available huge boxes sure theyre wanting save money ingredients theyre selling bulk buying',
#  'good stuff may bit expensive relation local products love sugar added found product local store half price would continue purchase cheaper option',
#  'bought start home yogurt making process made last night tasted yogurt made organic milk thing sour like little sour kick yogurt thing super sour making year old daughter doubt eat version probably modify add fruit something sweet make appetizing girl going try crushed granola bar see cut sourness guess suppose turn milk yogurt tasty one',
#  'product taste great always bake aswell original bisquick mix use original bisquick recipe substituting bisquick mix heartsmart bisquick mix might slight texture change reccomend baking biscuits mix come flat bit sweet tasting strange enough however cinnamon rolls pancakes taste good mix orginal close healthier choice',
#  'would recomend food chihuahuasan greyhound eat food free feed lost excessive weight eat eat still loose weight dogs healthy vet vet said food changed diet wk gained weight back lost',
#  'bought looking good glutenfree cereal theyre decent great little sweet going take get many boxes',
#  'seek real sushigrade unagi search amazon prepared pay instance plus shipping frozen barbequed marinated farmed fresh water eel unagi four piecesa tried probably sort stuff want item reviewed okay compared never eating eel tougher probably overcooked far less succulent genuine article offered sushi chefs another alternative smoked eel fillets boneless soybean oil cans pack gets highly variable reviews packed oil yuck clearly real unagi seek',
#  'love amazonbut product showed less months dating hot cocoa tastes great shocked short date even upsetting see nonreturnable item make sure read return policy make sure ready drink lot hot cocoa short period time',
#  'top kcup often loosens releases coffee coffee maker causing real mess']

# %% [markdown]
# Some examples from upper query:
#
#  'pretty good think really annoying claim bar equals two servings clearly doesnt aside pretty good dont think anyone really eats taste',
#
#  'sweet chocolate taste tried various family members appeal would definately recommend' # This is probably customer mistake
#
#  'bought looking good glutenfree cereal theyre decent great little sweet going take get many boxes' # Customer mistake
#
#  'decent coffee ridiculously overpriced starbucks ashamed charging buck half cup coffee made home' # This is a hard case for the model
#
#  'soup thick pleasant way bland one least favorite cups dr mcdougalls' # This is a hard case for the model
#
#  'expecting spicier regular wasabi peas actually less spicy good flavor would order' # This is a hard case for the model
#
# 'make mistake chocolate bar sweet maybe creamy overwhelmed sweetness couldnt taste anything else according label theres sugar within per chocolate decide' # This is a hard case for the model
